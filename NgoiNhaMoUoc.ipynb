# %%
import turtle
turtle.bgcolor("pink")
a = turtle.Turtle()
a.pensize(1)
a.speed(1000)
a.fillcolor("brown")
a.begin_fill()
a.penup()
a.goto(-150,-75)
a.pendown()
a.forward(300)
a.right(90)
a.forward(125)
a.right(90)
a.forward(300)
a.right(90)
a.forward(125)
a.end_fill()

a.begin_fill()
a.penup()
a.goto(-100,-75)
a.pendown()
a.forward(125)
a.right(90)
a.forward(200)
a.right(90)
a.forward(125)
a.right(90)
a.forward(200)
a.end_fill()

a.begin_fill()
a.penup()
a.goto(-50,50)
a.pendown()
a.right(90)
a.forward(125)
a.right(90)
a.forward(100)
a.right(90)
a.forward(125)
a.right(90)
a.goto(-50,50)
a.end_fill()

a.penup()
a.goto(-125,-200)
a.pendown()
a.fillcolor("gray")
a.begin_fill()
a.right(90)
a.forward(75)
for i in range(180):
    a.forward(0.5)
    a.right(1)
a.forward(75)
a.right(90)
a.goto(-125,-200)
a.end_fill()

a.penup()
a.goto(-25,-200)
a.pendown()
a.fillcolor("gray")
a.begin_fill()
a.right(90)
a.forward(75)
for i in range(180):
    a.forward(0.5)
    a.right(1)
a.forward(75)
a.right(90)
a.goto(-25,-200)
a.end_fill()

a.penup()
a.goto(75,-200)
a.pendown()
a.fillcolor("gray")
a.begin_fill()
a.right(90)
a.forward(75)
for i in range(180):
    a.forward(0.5)
    a.right(1)
a.forward(75)
a.right(90)
a.goto(75,-200)
a.end_fill()

a.penup()
a.goto(-75,-75)
a.pendown()
a.fillcolor("gray")
a.begin_fill()
a.right(90)
a.forward(75)
for i in range(180):
    a.forward(0.5)
    a.right(1)
a.forward(75)
a.right(90)
a.goto(-75,-75)
a.end_fill()

a.penup()
a.goto(25,-75)
a.pendown()
a.fillcolor("gray")
a.begin_fill()
a.right(90)
a.forward(75)
for i in range(180):
    a.forward(0.5)
    a.right(1)
a.forward(75)
a.right(90)
a.goto(25,-75)
a.end_fill()

a.penup()
a.goto(-25,50)
a.pendown()
a.fillcolor("gray")
a.begin_fill()
a.right(90)
a.forward(75)
for i in range(180):
    a.forward(0.5)
    a.right(1)
a.forward(75)
a.right(90)
a.goto(-25,50)
a.end_fill()

a.penup()
a.goto(-125,-200)
a.pendown()
a.fillcolor("black")
a.begin_fill()
a.right(135)
a.forward(79.5)
a.right(135)
a.forward(56.2)
a.right(90)
a.goto(-125,-200)
a.end_fill()

a.penup()
a.goto(-25,-200)
a.pendown()
a.fillcolor("black")
a.begin_fill()
a.right(135)
a.forward(79.5)
a.right(135)
a.forward(56.2)
a.right(90)
a.goto(-25,-200)
a.end_fill()

a.penup()
a.goto(75,-200)
a.pendown()
a.fillcolor("black")
a.begin_fill()
a.right(135)
a.forward(79.5)
a.right(135)
a.forward(56.2)
a.right(90)
a.goto(75,-200)
a.end_fill()

a.penup()
a.goto(-75,-75)
a.pendown()
a.fillcolor("black")
a.begin_fill()
a.right(135)
a.forward(79.5)
a.right(135)
a.forward(56.2)
a.right(90)
a.goto(-75,-75)
a.end_fill()

a.penup()
a.goto(25,-75)
a.pendown()
a.fillcolor("black")
a.begin_fill()
a.right(135)
a.forward(79.5)
a.right(135)
a.forward(56.2)
a.right(90)
a.goto(25,-75)
a.end_fill()

a.penup()
a.goto(-25,50)
a.pendown()
a.fillcolor("black")
a.begin_fill()
a.right(135)
a.forward(79.5)
a.right(135)
a.forward(56.2)
a.right(90)
a.goto(-25,50)
a.end_fill()

a.penup()
a.goto(-150,-75)
a.pendown()
a.fillcolor("brown")
a.begin_fill()
a.right(135)
a.goto(-100,-25)
a.goto(-100,-75)
a.goto(-150,-75)
a.end_fill()

a.penup()
a.goto(-100,50)
a.pendown()
a.fillcolor("brown")
a.begin_fill()
a.right(135)
a.goto(-50,100)
a.goto(-50,50)
a.goto(-100,50)
a.end_fill()

a.penup()
a.goto(-50,175)
a.pendown()
a.fillcolor("brown")
a.begin_fill()
a.goto(0,225)
a.goto(100,225)
a.goto(50,175)
a.goto(-50,175)
a.end_fill()

a.penup()
a.goto(50,175)
a.pendown()
a.fillcolor("brown")
a.begin_fill()
a.goto(100,225)
a.goto(100,100)
a.goto(50,50)
a.goto(50,175)
a.end_fill()

a.penup()
a.goto(100,100)
a.pendown()
a.fillcolor("brown")
a.begin_fill()
a.goto(50,50)
a.goto(100,50)
a.goto(150,100)
a.goto(100,100)
a.end_fill()

a.penup()
a.goto(150,100)
a.pendown()
a.fillcolor("brown")
a.begin_fill()
a.goto(100,50)
a.goto(100,-75)
a.goto(150,-25)
a.goto(150,100)
a.end_fill()

a.penup()
a.goto(150,-75)
a.pendown()
a.fillcolor("brown")
a.begin_fill()
a.goto(100,-75)
a.goto(150,-25)
a.goto(200,-25)
a.goto(150,-75)
a.end_fill()

a.penup()
a.goto(200,-25)
a.pendown()
a.fillcolor("brown")
a.begin_fill()
a.goto(150,-75)
a.goto(150,-200)
a.goto(200,-150)
a.goto(200,-25)
a.end_fill()

a.penup()
a.goto(-275,-300)
a.pendown()
a.fillcolor("orange")
a.begin_fill()
a.goto(-325,-300)
a.goto(-325,-50)
a.goto(-275,-50)
a.goto(-275,-300)
a.end_fill()

a.penup()
a.goto(-425,-50)
a.pendown()
a.fillcolor("green")
a.begin_fill()
a.goto(-300,75)
a.goto(-175,-50)
a.goto(-425,-50)
a.end_fill()

a.penup()
a.goto(-400,75)
a.pendown()
a.fillcolor("green")
a.begin_fill()
a.goto(-300,175)
a.goto(-200,75)
a.goto(-400,75)
a.end_fill()

a.penup()
a.goto(-375,175)
a.pendown()
a.fillcolor("green")
a.begin_fill()
a.goto(-300,250)
a.goto(-225,175)
a.goto(-375,175)
a.end_fill()

a.penup()
a.home()
a.goto(270,270)
a.pendown()
a.pensize(5)
a.pencolor("yellow")
a.fillcolor("yellow")
a.begin_fill()
for i in range(10):
    a.left(90)
    a.forward(85)
    a.backward(85)
    a.right(90)
    for i in range(36):
        a.forward(1)
        a.right(1)
a.end_fill()
turtle.done()
